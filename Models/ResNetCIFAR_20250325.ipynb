# %% [markdown]
# ## CIFAR Image Classigication using ResNet

# %% [markdown]
# ### System Check

# %%
import torch
import numpy as np

# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
  print('CUDA is not available.  Training on CPU ...')
else:
  print('CUDA is available!  Training on GPU ...')
# Out:
# CUDA is available!  Training on GPU ...

# %% [markdown]
# ## Load data

# %%
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data.sampler import SubsetRandomSampler

# number of subprocesses to use for data loading
num_workers = 0
# how many samples per batch to load
batch_size = 20
# percentage of training set to use as validation
valid_size = 0.2

# convert data to a normalized torch.FloatTensor
print('==> Preparing data..')
#Image augmentation is used to train the model
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])
#Only the data is normalaized we do not need to augment the test data
transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
])

# choose the training and test datasets
train_data = datasets.CIFAR10('data', train=True,
                              download=True, transform=transform_train)
test_data = datasets.CIFAR10('data', train=False,
                             download=True, transform=transform_test)

# obtain training indices that will be used for validation
num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]

# define samplers for obtaining training and validation batches
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

# prepare data loaders (combine dataset and sampler)
train_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size,
    sampler=train_sampler, num_workers=num_workers)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size=batch_size, 
    sampler=valid_sampler, num_workers=num_workers)
test_loader = torch.utils.data.DataLoader(test_data, batch_size=batch_size, 
    num_workers=num_workers)

# specify the image classes
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer',
           'dog', 'frog', 'horse', 'ship', 'truck']
# Out:
# ==> Preparing data..

# %% [markdown]
# ## Show pictures

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# helper function to un-normalize and display an image
def imshow(img):
  img = img / 2 + 0.5  # unnormalize
  plt.imshow(np.transpose(img, (1, 2, 0)))  # convert from Tensor image

# obtain one batch of training images
dataiter = iter(train_loader)
images, labels = next(dataiter)
images = images.numpy() # convert images to numpy for display

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(25, 4))
# display 20 images
for idx in np.arange(20):
  ax = fig.add_subplot(2, int(20/2), idx+1, xticks=[], yticks=[])
  imshow(images[idx])
  ax.set_title(classes[labels[idx]])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.3014984].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.564701].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.7988244].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.7598039].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.5427263].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.8378451].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.7207834].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..0.9331851].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.5939664].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.5728873].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.6891968].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.7207834].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.1842504].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.4640589].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6894605..1.8768656].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.82809].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.8768656].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.2378902].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.71453285..1.5549458].
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-0.6660706..1.6508939].

# %% [markdown]
# ### view one image in more detail

# %%
rgb_img = np.squeeze(images[3])
channels = ['red channel', 'green channel', 'blue channel']

fig = plt.figure(figsize = (36, 36)) 
for idx in np.arange(rgb_img.shape[0]):
  ax = fig.add_subplot(1, 3, idx + 1)
  img = rgb_img[idx]
  ax.imshow(img, cmap='gray')
  ax.set_title(channels[idx])
  width, height = img.shape
  thresh = img.max()/2.5  
  for x in range(width):
    for y in range(height):
      val = round(img[x][y],2) if img[x][y] !=0 else 0
      ax.annotate(str(val), xy=(y,x),
      horizontalalignment='center',
      verticalalignment='center', size=8,
      color='white' if img[x][y]<thresh else 'black')

# %% [markdown]
# ### Model definition

# %%
import torch.backends.cudnn as cudnn
import torch.nn as nn
import torch.nn.functional as F

class BasicBlock(nn.Module):
  expansion = 1
  def __init__(self, in_planes, planes, stride=1):
    super(BasicBlock, self).__init__()
    self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)

    self.shortcut = nn.Sequential()
    if stride != 1 or in_planes != self.expansion*planes:
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
          nn.BatchNorm2d(self.expansion*planes)
      )
  
  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.bn2(self.conv2(out))
    out += self.shortcut(x)
    out = F.relu(out)
    return out

class BottleNeck(nn.Module):
  expansion = 4

  def __init__(self, in_planes, planes, stride=1):
    super(BottleNeck, self).__init__()
    self.conv1 = nn.Conv2d(in_planes , planes, kernel_size=1, bias=False)
    self.bn1 = nn.BatchNorm2d(planes)
    self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
    self.bn2 = nn.BatchNorm2d(planes)
    self.conv3 = nn.Conv2d(planes, self.expansion*planes, kernel_size=1, bias=False)
    self.bn3 = nn.BatchNorm2d(self.expansion*planes)

    self.shortcut = nn.Sequential()
    if stride != 1 or in_planes != self.expansion*planes :
      self.shortcut = nn.Sequential(
          nn.Conv2d(in_planes, self.expansion*planes, kernel_size=1, stride=stride, bias=False),
          nn.BatchNorm2d(self.expansion*planes)
      )

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = F.relu(self.bn2(self.conv2(out)))
    out = self.bn3(self.conv3(out))
    out += self.shortcut(x)
    out = F.relu(out)
    return out

class ResNet(nn.Module):
  def __init__(self, block, num_blocks, num_classes=10):
    super(ResNet, self).__init__()
    self.in_planes = 64

    self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
    self.bn1 = nn.BatchNorm2d(64)
    self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
    self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
    self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
    self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
    self.linear = nn.Linear(512*block.expansion, num_classes)

  def _make_layer(self, block, planes, num_blocks, stride):
    strides = [stride] + [1]*(num_blocks-1)
    layers = []
    for stride in strides:
      layers.append(block(self.in_planes, planes, stride))
      self.in_planes = planes * block.expansion      
    return nn.Sequential(*layers)

  def forward(self, x):
    out = F.relu(self.bn1(self.conv1(x)))
    out = self.layer1(out)
    out = self.layer2(out)
    out = self.layer3(out)
    out = self.layer4(out)
    out = F.avg_pool2d(out, 4)
    out = out.view(out.size(0), -1)
    out = self.linear(out)
    return out

ResNet18 = ResNet(BasicBlock, [2,2,2,2])
#ResNet34 = ResNet(BasicBlock, [3,4,6,3])
#ResNet50 = ResNet(BottleNeck, [3,4,6,3])
#ResNet101 = ResNet(BottleNeck, [3,4,23,3])
#ResNet152 = ResNet(BottleNeck, [3,8,36,3])

print(ResNet18)

if train_on_gpu:
  ResNet18 = torch.nn.DataParallel(ResNet18)
  cudnn.benchmark = True
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (shortcut): Sequential()
#     )
#   )
#   (linear): Linear(in_features=512, out_features=10, bias=True)
# )

# %% [markdown]
# ## loss

# %%
import torch.optim as optim
# specify loss function (categorical cross-entropy)
criterion = nn.CrossEntropyLoss()

# specify optimizer
optimizer = optim.SGD(ResNet18.parameters(), lr=0.01, momentum=0.9, weight_decay=0.0001)

# %% [markdown]
# # train

# %%
# number of epochs to train the model
n_epochs = 200

valid_loss_min = np.Inf # track change in validation loss

for epoch in range(1, n_epochs+1):
  # keep track of training and validation loss
  train_loss = 0.0
  valid_loss = 0.0
    
  ###################
  # train the model #
  ###################
  ResNet18.train()
  for batch_idx, (data, target) in enumerate(train_loader):
    # move tensors to GPU if CUDA is available
    if train_on_gpu:
      data, target = data.cuda(), target.cuda()
    # clear the gradients of all optimized variables
    optimizer.zero_grad()
    # forward pass: compute predicted outputs by passing inputs to the model
    output = ResNet18(data)
    # calculate the batch loss
    loss = criterion(output, target)
    # backward pass: compute gradient of the loss with respect to model parameters
    loss.backward()
    # perform a single optimization step (parameter update)
    optimizer.step()
    # update training loss
    train_loss += loss.item()*data.size(0)
        
  ######################    
  # validate the model #
  ######################
  ResNet18.eval()
  for batch_idx, (data, target) in enumerate(valid_loader):
    # move tensors to GPU if CUDA is available
    if train_on_gpu:
      data, target = data.cuda(), target.cuda()
    # forward pass: compute predicted outputs by passing inputs to the model
    output = ResNet18(data)
    # calculate the batch loss
    loss = criterion(output, target)
    # update average validation loss 
    valid_loss += loss.item()*data.size(0)
    
  # calculate average losses
  train_loss = train_loss/len(train_loader.sampler)
  valid_loss = valid_loss/len(valid_loader.sampler)
        
  # print training/validation statistics 
  print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
      epoch, train_loss, valid_loss))
    
  # save model if validation loss has decreased
  if valid_loss <= valid_loss_min:
    print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
    valid_loss_min,
    valid_loss))
    torch.save(ResNet18.state_dict(), 'ResNet18.pt')
    valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 1.667295 	Validation Loss: 1.252174
# Validation loss decreased (inf --> 1.252174).  Saving model ...
# Epoch: 2 	Training Loss: 1.129490 	Validation Loss: 0.977657
# Validation loss decreased (1.252174 --> 0.977657).  Saving model ...
# Epoch: 3 	Training Loss: 0.888608 	Validation Loss: 0.838566
# Validation loss decreased (0.977657 --> 0.838566).  Saving model ...
# Epoch: 4 	Training Loss: 0.745741 	Validation Loss: 0.690243
# Validation loss decreased (0.838566 --> 0.690243).  Saving model ...
# Epoch: 5 	Training Loss: 0.639735 	Validation Loss: 0.668222
# Validation loss decreased (0.690243 --> 0.668222).  Saving model ...
# Epoch: 6 	Training Loss: 0.571084 	Validation Loss: 0.569795
# Validation loss decreased (0.668222 --> 0.569795).  Saving model ...
# Epoch: 7 	Training Loss: 0.515980 	Validation Loss: 0.488330
# Validation loss decreased (0.569795 --> 0.488330).  Saving model ...
# Epoch: 8 	Training Loss: 0.468250 	Validation Loss: 0.501246
# Epoch: 9 	Training Loss: 0.434636 	Validation Loss: 0.474765
# Validation loss decreased (0.488330 --> 0.474765).  Saving model ...
# Epoch: 10 	Training Loss: 0.404107 	Validation Loss: 0.458498
# Validation loss decreased (0.474765 --> 0.458498).  Saving model ...
# Epoch: 11 	Training Loss: 0.373352 	Validation Loss: 0.470166
# Epoch: 12 	Training Loss: 0.348712 	Validation Loss: 0.395076
# Validation loss decreased (0.458498 --> 0.395076).  Saving model ...
# Epoch: 13 	Training Loss: 0.327763 	Validation Loss: 0.406878
# Epoch: 14 	Training Loss: 0.305577 	Validation Loss: 0.386100
# Validation loss decreased (0.395076 --> 0.386100).  Saving model ...
# Epoch: 15 	Training Loss: 0.291515 	Validation Loss: 0.409251
# Epoch: 16 	Training Loss: 0.273514 	Validation Loss: 0.358628
# Validation loss decreased (0.386100 --> 0.358628).  Saving model ...
# Epoch: 17 	Training Loss: 0.258069 	Validation Loss: 0.355165
# Validation loss decreased (0.358628 --> 0.355165).  Saving model ...
# Epoch: 18 	Training Loss: 0.244198 	Validation Loss: 0.396875
# Epoch: 19 	Training Loss: 0.230267 	Validation Loss: 0.342033
# Validation loss decreased (0.355165 --> 0.342033).  Saving model ...
# Epoch: 20 	Training Loss: 0.220545 	Validation Loss: 0.354466
# Epoch: 21 	Training Loss: 0.208597 	Validation Loss: 0.364979
# Epoch: 22 	Training Loss: 0.200524 	Validation Loss: 0.334769
# Validation loss decreased (0.342033 --> 0.334769).  Saving model ...
# Epoch: 23 	Training Loss: 0.186614 	Validation Loss: 0.361869
# Epoch: 24 	Training Loss: 0.182423 	Validation Loss: 0.335257
# Epoch: 25 	Training Loss: 0.173436 	Validation Loss: 0.349736
# Epoch: 26 	Training Loss: 0.163906 	Validation Loss: 0.338070
# Epoch: 27 	Training Loss: 0.159981 	Validation Loss: 0.323233
# Validation loss decreased (0.334769 --> 0.323233).  Saving model ...
# Epoch: 28 	Training Loss: 0.155595 	Validation Loss: 0.318677
# Validation loss decreased (0.323233 --> 0.318677).  Saving model ...
# Epoch: 29 	Training Loss: 0.145993 	Validation Loss: 0.316799
# Validation loss decreased (0.318677 --> 0.316799).  Saving model ...
# Epoch: 30 	Training Loss: 0.142401 	Validation Loss: 0.334955
# Epoch: 31 	Training Loss: 0.132429 	Validation Loss: 0.334367
# Epoch: 32 	Training Loss: 0.131824 	Validation Loss: 0.357063
# Epoch: 33 	Training Loss: 0.126927 	Validation Loss: 0.319996
# Epoch: 34 	Training Loss: 0.127477 	Validation Loss: 0.352734
# Epoch: 35 	Training Loss: 0.124606 	Validation Loss: 0.324552
# Epoch: 36 	Training Loss: 0.118258 	Validation Loss: 0.321442
# Epoch: 37 	Training Loss: 0.111337 	Validation Loss: 0.321057
# Epoch: 38 	Training Loss: 0.111940 	Validation Loss: 0.316817
# Epoch: 39 	Training Loss: 0.107269 	Validation Loss: 0.358838
# Epoch: 40 	Training Loss: 0.103704 	Validation Loss: 0.317427
# Epoch: 41 	Training Loss: 0.102607 	Validation Loss: 0.333080
# Epoch: 42 	Training Loss: 0.100867 	Validation Loss: 0.319165
# Epoch: 43 	Training Loss: 0.095163 	Validation Loss: 0.327888
# Epoch: 44 	Training Loss: 0.095397 	Validation Loss: 0.337157
# Epoch: 45 	Training Loss: 0.096840 	Validation Loss: 0.337474
# Epoch: 46 	Training Loss: 0.094437 	Validation Loss: 0.311972
# Validation loss decreased (0.316799 --> 0.311972).  Saving model ...
# Epoch: 47 	Training Loss: 0.087137 	Validation Loss: 0.364774
# Epoch: 48 	Training Loss: 0.092543 	Validation Loss: 0.325624
# Epoch: 49 	Training Loss: 0.088960 	Validation Loss: 0.329513
# Epoch: 50 	Training Loss: 0.084324 	Validation Loss: 0.375341
# Epoch: 51 	Training Loss: 0.086159 	Validation Loss: 0.352433
# Epoch: 52 	Training Loss: 0.077931 	Validation Loss: 0.319071
# Epoch: 53 	Training Loss: 0.084690 	Validation Loss: 0.353225
# Epoch: 54 	Training Loss: 0.084226 	Validation Loss: 0.339942
# Epoch: 55 	Training Loss: 0.079664 	Validation Loss: 0.314092
# Epoch: 56 	Training Loss: 0.080350 	Validation Loss: 0.324443
# Epoch: 57 	Training Loss: 0.079905 	Validation Loss: 0.354973
# Epoch: 58 	Training Loss: 0.080914 	Validation Loss: 0.318679
# Epoch: 59 	Training Loss: 0.080955 	Validation Loss: 0.313813
# Epoch: 60 	Training Loss: 0.073864 	Validation Loss: 0.381562
# Epoch: 61 	Training Loss: 0.081349 	Validation Loss: 0.326925
# Epoch: 62 	Training Loss: 0.072217 	Validation Loss: 0.347175
# Epoch: 63 	Training Loss: 0.079827 	Validation Loss: 0.327718
# Epoch: 64 	Training Loss: 0.074256 	Validation Loss: 0.322163
# Epoch: 65 	Training Loss: 0.080439 	Validation Loss: 0.327317
# Epoch: 66 	Training Loss: 0.072296 	Validation Loss: 0.346125
# Epoch: 67 	Training Loss: 0.074164 	Validation Loss: 0.339455
# Epoch: 68 	Training Loss: 0.072970 	Validation Loss: 0.369237
# Epoch: 69 	Training Loss: 0.067623 	Validation Loss: 0.323735
# Epoch: 70 	Training Loss: 0.072041 	Validation Loss: 0.326090
# Epoch: 71 	Training Loss: 0.068276 	Validation Loss: 0.350617
# Epoch: 72 	Training Loss: 0.075071 	Validation Loss: 0.346926
# Epoch: 73 	Training Loss: 0.070896 	Validation Loss: 0.359502
# Epoch: 74 	Training Loss: 0.069923 	Validation Loss: 0.352363
# Epoch: 75 	Training Loss: 0.073747 	Validation Loss: 0.328438
# Epoch: 76 	Training Loss: 0.068784 	Validation Loss: 0.382203
# Epoch: 77 	Training Loss: 0.072114 	Validation Loss: 0.343201
# Epoch: 78 	Training Loss: 0.069168 	Validation Loss: 0.317959
# Epoch: 79 	Training Loss: 0.070016 	Validation Loss: 0.342098
# Epoch: 80 	Training Loss: 0.065032 	Validation Loss: 0.326507
# Epoch: 81 	Training Loss: 0.072580 	Validation Loss: 0.352545
# Epoch: 82 	Training Loss: 0.069726 	Validation Loss: 0.331825
# Epoch: 83 	Training Loss: 0.075456 	Validation Loss: 0.356334
# Epoch: 84 	Training Loss: 0.064876 	Validation Loss: 0.348798
# Epoch: 85 	Training Loss: 0.068372 	Validation Loss: 0.297751
# Validation loss decreased (0.311972 --> 0.297751).  Saving model ...
# Epoch: 86 	Training Loss: 0.062700 	Validation Loss: 0.324434
# Epoch: 87 	Training Loss: 0.070349 	Validation Loss: 0.327211
# Epoch: 88 	Training Loss: 0.069363 	Validation Loss: 0.331987
# Epoch: 89 	Training Loss: 0.069618 	Validation Loss: 0.329877
# Epoch: 90 	Training Loss: 0.067275 	Validation Loss: 0.323429
# Epoch: 91 	Training Loss: 0.060513 	Validation Loss: 0.333436
# Epoch: 92 	Training Loss: 0.066271 	Validation Loss: 0.327009
# Epoch: 93 	Training Loss: 0.068645 	Validation Loss: 0.307316
# Epoch: 94 	Training Loss: 0.062600 	Validation Loss: 0.357978
# Epoch: 95 	Training Loss: 0.070093 	Validation Loss: 0.317089
# Epoch: 96 	Training Loss: 0.062864 	Validation Loss: 0.348144
# Epoch: 97 	Training Loss: 0.064175 	Validation Loss: 0.304718
# Epoch: 98 	Training Loss: 0.060897 	Validation Loss: 0.320384
# Epoch: 99 	Training Loss: 0.070883 	Validation Loss: 0.319436
# Epoch: 100 	Training Loss: 0.063321 	Validation Loss: 0.315535
# Epoch: 101 	Training Loss: 0.065234 	Validation Loss: 0.310654
# Epoch: 102 	Training Loss: 0.062112 	Validation Loss: 0.313398
# Epoch: 103 	Training Loss: 0.061621 	Validation Loss: 0.347432
# Epoch: 104 	Training Loss: 0.064986 	Validation Loss: 0.339670
# Epoch: 105 	Training Loss: 0.064962 	Validation Loss: 0.344953
# Epoch: 106 	Training Loss: 0.067675 	Validation Loss: 0.347298
# Epoch: 107 	Training Loss: 0.062422 	Validation Loss: 0.343158
# Epoch: 108 	Training Loss: 0.062026 	Validation Loss: 0.328823
# Epoch: 109 	Training Loss: 0.061433 	Validation Loss: 0.316688
# Epoch: 110 	Training Loss: 0.063665 	Validation Loss: 0.346287
# Epoch: 111 	Training Loss: 0.065921 	Validation Loss: 0.310280
# Epoch: 112 	Training Loss: 0.059600 	Validation Loss: 0.353959
# Epoch: 113 	Training Loss: 0.059195 	Validation Loss: 0.329696
# Epoch: 114 	Training Loss: 0.062069 	Validation Loss: 0.298878
# Epoch: 115 	Training Loss: 0.061021 	Validation Loss: 0.352479
# Epoch: 116 	Training Loss: 0.062752 	Validation Loss: 0.315047
# Epoch: 117 	Training Loss: 0.063433 	Validation Loss: 0.341011
# Epoch: 118 	Training Loss: 0.067466 	Validation Loss: 0.335239
# Epoch: 119 	Training Loss: 0.060594 	Validation Loss: 0.321209
# Epoch: 120 	Training Loss: 0.062534 	Validation Loss: 0.328913
# Epoch: 121 	Training Loss: 0.063790 	Validation Loss: 0.318961
# Epoch: 122 	Training Loss: 0.059600 	Validation Loss: 0.355053
# Epoch: 123 	Training Loss: 0.064829 	Validation Loss: 0.339117
# Epoch: 124 	Training Loss: 0.059715 	Validation Loss: 0.341049
# Epoch: 125 	Training Loss: 0.067018 	Validation Loss: 0.329553
# Epoch: 126 	Training Loss: 0.059359 	Validation Loss: 0.356443
# Epoch: 127 	Training Loss: 0.060810 	Validation Loss: 0.337102
# Epoch: 128 	Training Loss: 0.062159 	Validation Loss: 0.324211
# Epoch: 129 	Training Loss: 0.061954 	Validation Loss: 0.356297
# Epoch: 130 	Training Loss: 0.059287 	Validation Loss: 0.338236
# Epoch: 131 	Training Loss: 0.065285 	Validation Loss: 0.308695
# Epoch: 132 	Training Loss: 0.058078 	Validation Loss: 0.364172
# Epoch: 133 	Training Loss: 0.066000 	Validation Loss: 0.323304
# Epoch: 134 	Training Loss: 0.061836 	Validation Loss: 0.343218
# Epoch: 135 	Training Loss: 0.059138 	Validation Loss: 0.339370
# Epoch: 136 	Training Loss: 0.057885 	Validation Loss: 0.316753
# Epoch: 137 	Training Loss: 0.057110 	Validation Loss: 0.304724
# Epoch: 138 	Training Loss: 0.059486 	Validation Loss: 0.346948
# Epoch: 139 	Training Loss: 0.065241 	Validation Loss: 0.320179
# Epoch: 140 	Training Loss: 0.055955 	Validation Loss: 0.350195
# Epoch: 141 	Training Loss: 0.060527 	Validation Loss: 0.317341
# Epoch: 142 	Training Loss: 0.057618 	Validation Loss: 0.343256
# Epoch: 143 	Training Loss: 0.063289 	Validation Loss: 0.300905
# Epoch: 144 	Training Loss: 0.059468 	Validation Loss: 0.352322
# Epoch: 145 	Training Loss: 0.061141 	Validation Loss: 0.342285
# Epoch: 146 	Training Loss: 0.056123 	Validation Loss: 0.326641
# Epoch: 147 	Training Loss: 0.059611 	Validation Loss: 0.362971
# Epoch: 148 	Training Loss: 0.060538 	Validation Loss: 0.319824
# Epoch: 149 	Training Loss: 0.059700 	Validation Loss: 0.315680
# Epoch: 150 	Training Loss: 0.058571 	Validation Loss: 0.329498
# Epoch: 151 	Training Loss: 0.055941 	Validation Loss: 0.369715
# Epoch: 152 	Training Loss: 0.057899 	Validation Loss: 0.361843
# Epoch: 153 	Training Loss: 0.060421 	Validation Loss: 0.336525
# Epoch: 154 	Training Loss: 0.061086 	Validation Loss: 0.357350
# Epoch: 155 	Training Loss: 0.058271 	Validation Loss: 0.331160
# Epoch: 156 	Training Loss: 0.061171 	Validation Loss: 0.326378
# Epoch: 157 	Training Loss: 0.058758 	Validation Loss: 0.300457
# Epoch: 158 	Training Loss: 0.056420 	Validation Loss: 0.311522
# Epoch: 159 	Training Loss: 0.062367 	Validation Loss: 0.349276
# Epoch: 160 	Training Loss: 0.057194 	Validation Loss: 0.340684
# Epoch: 161 	Training Loss: 0.055402 	Validation Loss: 0.314979
# Epoch: 162 	Training Loss: 0.053643 	Validation Loss: 0.352273
# Epoch: 163 	Training Loss: 0.060873 	Validation Loss: 0.307696
# Epoch: 164 	Training Loss: 0.061654 	Validation Loss: 0.315803
# Epoch: 165 	Training Loss: 0.059729 	Validation Loss: 0.324766
# Epoch: 166 	Training Loss: 0.058404 	Validation Loss: 0.331371
# Epoch: 167 	Training Loss: 0.064127 	Validation Loss: 0.325700
# Epoch: 168 	Training Loss: 0.062804 	Validation Loss: 0.308304
# Epoch: 169 	Training Loss: 0.054794 	Validation Loss: 0.330830
# Epoch: 170 	Training Loss: 0.057012 	Validation Loss: 0.303322
# Epoch: 171 	Training Loss: 0.052868 	Validation Loss: 0.356497
# Epoch: 172 	Training Loss: 0.054563 	Validation Loss: 0.325132
# Epoch: 173 	Training Loss: 0.056063 	Validation Loss: 0.328993
# Epoch: 174 	Training Loss: 0.061071 	Validation Loss: 0.335759
# Epoch: 175 	Training Loss: 0.057153 	Validation Loss: 0.347380
# Epoch: 176 	Training Loss: 0.061785 	Validation Loss: 0.311235
# Epoch: 177 	Training Loss: 0.057709 	Validation Loss: 0.335750
# Epoch: 178 	Training Loss: 0.059149 	Validation Loss: 0.345963
# Epoch: 179 	Training Loss: 0.057591 	Validation Loss: 0.320227
# Epoch: 180 	Training Loss: 0.051961 	Validation Loss: 0.323772
# Epoch: 181 	Training Loss: 0.059106 	Validation Loss: 0.342793
# Epoch: 182 	Training Loss: 0.059442 	Validation Loss: 0.305384
# Epoch: 183 	Training Loss: 0.061505 	Validation Loss: 0.311602
# Epoch: 184 	Training Loss: 0.054695 	Validation Loss: 0.319633
# Epoch: 185 	Training Loss: 0.059391 	Validation Loss: 0.313260
# Epoch: 186 	Training Loss: 0.053171 	Validation Loss: 0.337625
# Epoch: 187 	Training Loss: 0.053852 	Validation Loss: 0.348113
# Epoch: 188 	Training Loss: 0.063054 	Validation Loss: 0.376712
# Epoch: 189 	Training Loss: 0.059375 	Validation Loss: 0.328301
# Epoch: 190 	Training Loss: 0.056146 	Validation Loss: 0.391372
# Epoch: 191 	Training Loss: 0.059258 	Validation Loss: 0.374211
# Epoch: 192 	Training Loss: 0.055292 	Validation Loss: 0.413529
# Epoch: 193 	Training Loss: 0.056885 	Validation Loss: 0.338447
# Epoch: 194 	Training Loss: 0.056165 	Validation Loss: 0.322597
# Epoch: 195 	Training Loss: 0.055448 	Validation Loss: 0.302583
# Epoch: 196 	Training Loss: 0.059165 	Validation Loss: 0.320000
# Epoch: 197 	Training Loss: 0.057961 	Validation Loss: 0.331611
# Epoch: 198 	Training Loss: 0.053300 	Validation Loss: 0.286838
# Validation loss decreased (0.297751 --> 0.286838).  Saving model ...
# Epoch: 199 	Training Loss: 0.056968 	Validation Loss: 0.347093
# Epoch: 200 	Training Loss: 0.059750 	Validation Loss: 0.319262

# %% [markdown]
# # load best

# %%
ResNet18.load_state_dict(torch.load('ResNet18.pt'))
# Out:
# <All keys matched successfully>

# %%
# track test loss
test_loss = 0.0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

ResNet18.eval()
# iterate over test data
for batch_idx, (data, target) in enumerate(test_loader):
  # move tensors to GPU if CUDA is available
  if train_on_gpu:
    data, target = data.cuda(), target.cuda()
  # forward pass: compute predicted outputs by passing inputs to the model
  output = ResNet18(data)
  # calculate the batch loss
  loss = criterion(output, target)
  # update test loss 
  test_loss += loss.item()*data.size(0)
  # convert output probabilities to predicted class
  _, pred = torch.max(output, 1)    
  # compare predictions to true label
  correct_tensor = pred.eq(target.data.view_as(pred))
  correct = np.squeeze(correct_tensor.numpy()) if not train_on_gpu else np.squeeze(correct_tensor.cpu().numpy())
  # calculate test accuracy for each object class
  for i in range(batch_size):
    label = target.data[i]
    class_correct[label] += correct[i].item()
    class_total[label] += 1

# average test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))

for i in range(10):
  if class_total[i] > 0:
    print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
        classes[i], 100 * class_correct[i] / class_total[i],
        np.sum(class_correct[i]), np.sum(class_total[i])))
  else:
    print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.321205
#
# Test Accuracy of airplane: 91% (915/1000)
# Test Accuracy of automobile: 93% (936/1000)
# Test Accuracy of  bird: 88% (880/1000)
# Test Accuracy of   cat: 82% (828/1000)
# Test Accuracy of  deer: 95% (954/1000)
# Test Accuracy of   dog: 88% (886/1000)
# Test Accuracy of  frog: 93% (938/1000)
# Test Accuracy of horse: 92% (927/1000)
# Test Accuracy of  ship: 95% (957/1000)
# Test Accuracy of truck: 97% (970/1000)
#
# Test Accuracy (Overall): 91% (9191/10000)
